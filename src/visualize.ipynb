# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from saliency import saliency
import pylab

arr = saliency.load("./CDR_saliency/cor_type_1.pkl").mat
# ax = sns.heatmap(arr, cmap='RdBu_r')

pylab.imshow(arr, cmap="hot")
# pylab.show()
